# %%
# %pip install lifelines

# %%
# %restart_python

# %%
import lifelines
print("lifelines installed successfully")

# %%
import sys
print(sys.executable)
print(sys.path[:3])

# %%
import importlib.util
print(importlib.util.find_spec("lifelines"))

# %%
# %pip install lifelines
dbutils.library.restartPython()

# %%
import sys, subprocess, importlib.util

print("Python:", sys.executable)
print("lifelines spec:", importlib.util.find_spec("lifelines"))

# Also verify via pip in THIS python env:
print(subprocess.check_output([sys.executable, "-m", "pip", "show", "lifelines"]).decode())
